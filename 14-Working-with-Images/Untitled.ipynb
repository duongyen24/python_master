# %%
from PIL import Image

# %%
mac = Image.open('example.jpg')

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x228B42FBE80>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
pencil = Image.open('pencils.jpg')

# %%
pencil.size
# Out:
# (1950, 1300)

# %%
x=0
y=0
w = 1950*0.3
h=1300*0.1

# %%
pencil.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=585x130 at 0x228B4327EE0>
